# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamadRayi/MachineLearningTasks/blob/main/A_demo_of_the_mean_shift_clustering_algorithm_Rayi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mohamad Rayi Dwi Putra
# 1103213070
# Task 6 Clustering
# A demo of the mean-shift clustering algorithm

# %% [markdown]
# **Generate sample data**

# %%
from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.datasets import make_blobs

# Membuat data sintetis
centers = [[1, 1], [-1, -1], [1, -1]]
X, _ = make_blobs(n_samples=10000, centers=centers, cluster_std=0.6)

# Mengestimasi bandwidth
bandwidth = estimate_bandwidth(X, quantile=0.2, n_samples=500)

# Melakukan clustering menggunakan MeanShift
ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(X)
# Out:
# MeanShift(bandwidth=1.0262155438747773, bin_seeding=True)

# %% [markdown]
# **Compute clustering with MeanShift**

# %%
from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.datasets import make_blobs
import numpy as np

# Membuat data sintetis
centers = [[1, 1], [-1, -1], [1, -1]]
X, _ = make_blobs(n_samples=10000, centers=centers, cluster_std=0.6)

# Mengestimasi bandwidth
bandwidth = estimate_bandwidth(X, quantile=0.2, n_samples=500)

# Melakukan clustering menggunakan MeanShift
ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(X)

# Mendapatkan label klaster dan pusat klaster
labels = ms.labels_
cluster_centers = ms.cluster_centers_

# Mendapatkan jumlah klaster yang diestimasi
labels_unique = np.unique(labels)
n_clusters_ = len(labels_unique)

print("number of estimated clusters : %d" % n_clusters_)
# Out:
# number of estimated clusters : 3

# %% [markdown]
# **Plot result**

# %%
import matplotlib.pyplot as plt

plt.figure(1)
plt.clf()

colors = ["#dede00", "#377eb8", "#f781bf"]
markers = ["x", "o", "^"]

for k, col in zip(range(n_clusters_), colors):
    my_members = labels == k
    cluster_center = cluster_centers[k]
    plt.plot(X[my_members, 0], X[my_members, 1], markers[k], color=col)
    plt.plot(
        cluster_center[0],
        cluster_center[1],
        markers[k],
        markerfacecolor=col,
        markeredgecolor="k",
        markersize=14,
    )
plt.title("Estimated number of clusters: %d" % n_clusters_)
plt.show()
